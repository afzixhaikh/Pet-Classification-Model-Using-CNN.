# %%
# Part 1 - Building the CNN
# Importing the Keras libraries and packages
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
import tensorflow.keras

# %%
# ● Input layer 
# ● Convolutional layer 1 with 32 filters of kernel size[5,5] 
# ● Pooling layer 1 with pool size[2,2] and stride 2 
# ● Convolutional layer 2 with 64 filters of kernel size[5,5] 
# ● Pooling layer 2 with pool size[2,2] and stride 2 
# ● Dense layer whose output size is fixed in the hyper parameter: fc_size=32 
# ● Dropout layer with dropout probability 0.4 
# Predict the class by doing a softmax on the output of the dropout layers. 
# This should be followed by training and evaluation: 
# ● For the training step, define the loss function and minimize it 
# ● For the evaluation step, calculate the accuracy 
# Run the program for 100, 200, and 300 iterations, respectively. Follow this by a report on the final accuracy and loss on the evaluation data.

# %%
# Part 2 - Fitting the CNN to the images
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.1,
                                   zoom_range = 0.1,
                                   horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('D:/Deep_Learning_Simplilearn/1577957291_deeplearningwithkerasandtensorflow/data/train/',
                                                 target_size = (64, 64),
                                                 batch_size = 4,
                                                 class_mode = 'binary')
# Out:
# Found 40 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory('D:/Deep_Learning_Simplilearn/1577957291_deeplearningwithkerasandtensorflow/data/test/',
                                            target_size = (64, 64),
                                            batch_size = 4,
                                            class_mode = 'binary')
# Out:
# Found 20 images belonging to 2 classes.

# %%
# plot dog photos from the dogs vs cats dataset
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset
folder = 'D:/Deep_Learning_Simplilearn/1577957291_deeplearningwithkerasandtensorflow/data/train/dogs/'
# plot first few images
for i in range(9):
    # define subplot
    pyplot.subplot(330 + 1 + i)
    # define filename
    filename = folder + str(i+1) + '.jpg'
    # load image pixels
    image = imread(filename)
    # plot raw pixel data
    pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# plot dog photos from the dogs vs cats dataset
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset
folder = 'D:/Deep_Learning_Simplilearn/1577957291_deeplearningwithkerasandtensorflow/data/train/cats/'
# plot first few images
for i in range(9):
    # define subplot
    pyplot.subplot(330 + 1 + i)
    # define filename
    filename = folder + str(i+1) + '.jpg'
    # load image pixels
    image = imread(filename)
    # plot raw pixel data
    pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# Initialising the CNN
classifier = Sequential()

# %%
# Step 1 - Convolution
classifier.add(Conv2D(32, (5, 5), input_shape = (64, 64, 3), activation = 'relu'))
# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2), strides = 2))
# Adding a second convolutional layer
classifier.add(Conv2D(64, (5, 5), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2), strides = 2))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 32, activation = 'relu' ))
classifier.add(Dropout(0.4))
               
classifier.add(Dense(units = 1, activation = 'softmax'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(training_set,                         
                         epochs = 100,
                         validation_data = test_set
                         );
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 68ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 2/100
# 10/10 [==============================] - 0s 48ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 3/100
# 10/10 [==============================] - 0s 44ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 4/100
# 10/10 [==============================] - 0s 43ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 5/100
# 10/10 [==============================] - 0s 45ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 6/100
# 10/10 [==============================] - 0s 45ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 7/100
# ...

# %%
classifier.fit(training_set,                         
                         epochs = 200,
                         validation_data = test_set
                         );
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 50ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 2/200
# 10/10 [==============================] - 0s 50ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 3/200
# 10/10 [==============================] - 0s 46ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 4/200
# 10/10 [==============================] - 1s 55ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 5/200
# 10/10 [==============================] - 0s 48ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 6/200
# 10/10 [==============================] - 0s 50ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 7/200
# ...

# %%
classifier.fit(training_set,                         
                         epochs = 300,
                         validation_data = test_set
                         );
# Out:
# Epoch 1/300
# 10/10 [==============================] - 0s 49ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 2/300
# 10/10 [==============================] - 0s 48ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 3/300
# 10/10 [==============================] - 0s 47ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 4/300
# 10/10 [==============================] - 0s 47ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 5/300
# 10/10 [==============================] - 0s 47ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 6/300
# 10/10 [==============================] - 0s 45ms/step - loss: 7.6246 - accuracy: 0.5000 - val_loss: 7.6246 - val_accuracy: 0.5000
# Epoch 7/300
# ...
